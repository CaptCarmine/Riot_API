# %%
import requests
import json
import pandas as pd
# Import API key
from api import r_key

# %%
api_param={
    "api_key":r_key,
}

# %%
status_url = "https://na1.api.riotgames.com/lol/status/v3/shard-data"
summoner_url = 'https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Adventure'
game_url = 'https://na1.api.riotgames.com/lol/match/v4/matches/4036633413'

# %%
champ_data = requests.get("https://ddragon.leagueoflegends.com/cdn/11.18.1/data/en_US/champion.json")
champ_data_old = requests.get("https://ddragon.leagueoflegends.com/cdn/9.24.2/data/en_US/champion.json")

# %%
s_response = requests.get(status_url,api_param)
sum_response = requests.get(summoner_url,api_param)
game_response = requests.get(game_url,api_param)

# %%
game_response
# Out:
# <Response [200]>

# %%
s_response.json()['services'][0]
# Out:
# {'name': 'Game',
#  'slug': 'game',
#  'status': 'online',
#  'incidents': [{'id': 14190,
#    'active': True,
#    'created_at': '2019-12-09T16:08:18.580Z',
#    'updates': []},
#   {'id': 14383,
#    'active': True,
#    'created_at': '2020-01-22T02:27:05.671Z',
#    'updates': [{'id': '5e27b2f98d0391e7b7333f51',
#      'author': '',
#      'heading': '10.02',
#      'content': 'On 01/23/20, starting at, 01:30 Pacific Time (09:30 UTC), ranked queues will be disabled in preparation for patch 10.02. At 03:00 Pacific time (11:00 UTC), the servers will be shut down and all games currently in progress will end in a draw and stats will not be recorded. We estimate the battlegrounds will be unavailable for 3 hours.',
#      'severity': 'info',
#      'created_at': '2020-01-22T02:27:05.671Z',
#      'updated_at': '2020-01-22T02:27:05.671Z',
#      'translations': []}]},
#   {'id': 14440,
#    'active': True,
#    'created_at': '2020-02-04T02:21:37.928Z',
# ...

# %%
sum_response.json()
# Out:
# {'id': 'HgqHzU2SRWqsAJyMJi-0Jt61hGZC27O0Dgq7yyhv0sF8uNA',
#  'accountId': 'TR87imAoq-GjFkOcGM1CBTcRRdFKzDJTQsFX9gUPsywYaQ',
#  'puuid': 'QQgF_zQN9FSP2D_h3dnsRL9MEblFCls49C7VZoWyxxEiPq_FmTga31cEZj22XzEAa6fx3UwpvdmZtA',
#  'name': 'Adventure',
#  'profileIconId': 593,
#  'revisionDate': 1631335540000,
#  'summonerLevel': 110}

# %%
game_response.json()
# Out:
# {'gameId': 4036633413,
#  'platformId': 'NA1',
#  'gameCreation': 1631151528184,
#  'gameDuration': 1891,
#  'queueId': 400,
#  'mapId': 11,
#  'seasonId': 13,
#  'gameVersion': '11.17.394.4489',
#  'gameMode': 'CLASSIC',
#  'gameType': 'MATCHED_GAME',
#  'teams': [{'teamId': 100,
#    'win': 'Win',
#    'firstBlood': False,
#    'firstTower': True,
#    'firstInhibitor': True,
#    'firstBaron': True,
#    'firstDragon': False,
#    'firstRiftHerald': False,
#    'towerKills': 10,
#    'inhibitorKills': 2,
#    'baronKills': 1,
#    'dragonKills': 4,
#    'vilemawKills': 0,
#    'riftHeraldKills': 0,
#    'dominionVictoryScore': 0,
#    'bans': [{'championId': 1, 'pickTurn': 1},
#     {'championId': 161, 'pickTurn': 2},
#     {'championId': 516, 'pickTurn': 3},
#     {'championId': 35, 'pickTurn': 4},
#     {'championId': 202, 'pickTurn': 5}]},
#   {'teamId': 200,
#    'win': 'Fail',
#    'firstBlood': True,
#    'firstTower': False,
#    'firstInhibitor': False,
# ...

# %%
game_response.json()['participants'][8]
# Out:
# {'participantId': 9,
#  'teamId': 200,
#  'championId': 236,
#  'spell1Id': 4,
#  'spell2Id': 7,
#  'stats': {'participantId': 9,
#   'win': False,
#   'item0': 6694,
#   'item1': 3006,
#   'item2': 6671,
#   'item3': 3508,
#   'item4': 6676,
#   'item5': 3033,
#   'item6': 3340,
#   'kills': 21,
#   'deaths': 6,
#   'assists': 6,
#   'largestKillingSpree': 6,
#   'largestMultiKill': 2,
#   'killingSprees': 6,
#   'longestTimeSpentLiving': 401,
#   'doubleKills': 2,
#   'tripleKills': 0,
#   'quadraKills': 0,
#   'pentaKills': 0,
#   'unrealKills': 0,
#   'totalDamageDealt': 163879,
#   'magicDamageDealt': 12432,
#   'physicalDamageDealt': 144472,
#   'trueDamageDealt': 6974,
#   'largestCriticalStrike': 631,
#   'totalDamageDealtToChampions': 36241,
#   'magicDamageDealtToChampions': 7096,
#   'physicalDamageDealtToChampions': 28294,
#   'trueDamageDealtToChampions': 851,
#   'totalHeal': 7619,
#   'totalUnitsHealed': 3,
#   'damageSelfMitigated': 10452,
# ...

# %%
champ_data.json()
# Out:
# {'type': 'champion',
#  'format': 'standAloneComplex',
#  'version': '11.18.1',
#  'data': {'Aatrox': {'version': '11.18.1',
#    'id': 'Aatrox',
#    'key': '266',
#    'name': 'Aatrox',
#    'title': 'the Darkin Blade',
#    'blurb': 'Once honored defenders of Shurima against the Void, Aatrox and his brethren would eventually become an even greater threat to Runeterra, and were defeated only by cunning mortal sorcery. But after centuries of imprisonment, Aatrox was the first to find...',
#    'info': {'attack': 8, 'defense': 4, 'magic': 3, 'difficulty': 4},
#    'image': {'full': 'Aatrox.png',
#     'sprite': 'champion0.png',
#     'group': 'champion',
#     'x': 0,
#     'y': 0,
#     'w': 48,
#     'h': 48},
#    'tags': ['Fighter', 'Tank'],
#    'partype': 'Blood Well',
#    'stats': {'hp': 580,
#     'hpperlevel': 90,
#     'mp': 0,
#     'mpperlevel': 0,
#     'movespeed': 345,
#     'armor': 38,
#     'armorperlevel': 3.25,
#     'spellblock': 32,
# ...

# %%
champ_raw_data = champ_data.json()['data']
champ_raw_data
# Out:
# {'Aatrox': {'version': '11.18.1',
#   'id': 'Aatrox',
#   'key': '266',
#   'name': 'Aatrox',
#   'title': 'the Darkin Blade',
#   'blurb': 'Once honored defenders of Shurima against the Void, Aatrox and his brethren would eventually become an even greater threat to Runeterra, and were defeated only by cunning mortal sorcery. But after centuries of imprisonment, Aatrox was the first to find...',
#   'info': {'attack': 8, 'defense': 4, 'magic': 3, 'difficulty': 4},
#   'image': {'full': 'Aatrox.png',
#    'sprite': 'champion0.png',
#    'group': 'champion',
#    'x': 0,
#    'y': 0,
#    'w': 48,
#    'h': 48},
#   'tags': ['Fighter', 'Tank'],
#   'partype': 'Blood Well',
#   'stats': {'hp': 580,
#    'hpperlevel': 90,
#    'mp': 0,
#    'mpperlevel': 0,
#    'movespeed': 345,
#    'armor': 38,
#    'armorperlevel': 3.25,
#    'spellblock': 32,
#    'spellblockperlevel': 1.25,
#    'attackrange': 175,
#    'hpregen': 3,
#    'hpregenperlevel': 1,
#    'mpregen': 0,
# ...

# %%
champ_raw_data['Rammus']["id"]
# Out:
# {'version': '11.18.1',
#  'id': 'Rammus',
#  'key': '33',
#  'name': 'Rammus',
#  'title': 'the Armordillo',
#  'blurb': 'Idolized by many, dismissed by some, mystifying to all, the curious being Rammus is an enigma. Protected by a spiked shell, he inspires increasingly disparate theories on his origin wherever he goes—from demigod, to sacred oracle, to a mere beast...',
#  'info': {'attack': 4, 'defense': 10, 'magic': 5, 'difficulty': 5},
#  'image': {'full': 'Rammus.png',
#   'sprite': 'champion3.png',
#   'group': 'champion',
#   'x': 240,
#   'y': 0,
#   'w': 48,
#   'h': 48},
#  'tags': ['Tank', 'Fighter'],
#  'partype': 'Mana',
#  'stats': {'hp': 564,
#   'hpperlevel': 80,
#   'mp': 310,
#   'mpperlevel': 33,
#   'movespeed': 335,
#   'armor': 36,
#   'armorperlevel': 4.3,
#   'spellblock': 32,
#   'spellblockperlevel': 1.25,
#   'attackrange': 125,
#   'hpregen': 8,
#   'hpregenperlevel': 0.55,
#   'mpregen': 7.84,
#   'mpregenperlevel': 0.5,
#   'crit': 0,
# ...

# %%
print(f' name: {champ_raw_data["Rammus"]["id"]}')
print(f" hp: {champ_raw_data['Rammus']['stats']['hp']}")
# Out:
#  name: Rammus
#  hp: 564

# %%
champ_data.text
# Out:
# '{"type":"champion","format":"standAloneComplex","version":"11.18.1","data":{"Aatrox":{"version":"11.18.1","id":"Aatrox","key":"266","name":"Aatrox","title":"the Darkin Blade","blurb":"Once honored defenders of Shurima against the Void, Aatrox and his brethren would eventually become an even greater threat to Runeterra, and were defeated only by cunning mortal sorcery. But after centuries of imprisonment, Aatrox was the first to find...","info":{"attack":8,"defense":4,"magic":3,"difficulty":4},"image":{"full":"Aatrox.png","sprite":"champion0.png","group":"champion","x":0,"y":0,"w":48,"h":48},"tags":["Fighter","Tank"],"partype":"Blood Well","stats":{"hp":580,"hpperlevel":90,"mp":0,"mpperlevel":0,"movespeed":345,"armor":38,"armorperlevel":3.25,"spellblock":32,"spellblockperlevel":1.25,"attackrange":175,"hpregen":3,"hpregenperlevel":1,"mpregen":0,"mpregenperlevel":0,"crit":0,"critperlevel":0,"attackdamage":60,"attackdamageperlevel":5,"attackspeedperlevel":2.5,"attackspeed":0.651}},"Ahri
# ...

# %%
allchamps = []

for champ in champ_raw_data:
    name =
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26184/2283150927.py in <module>
# ----> 1 df = pd.read_json(champ_raw_data)
#
# ~\.conda\envs\MLenv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~\.conda\envs\MLenv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
